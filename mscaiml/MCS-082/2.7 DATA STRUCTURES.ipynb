# %%
# List addition
x = [1,2,3]
y = [0,1,2,4] 

print(x + y) 

print(x*3)
# Out:
# [1, 2, 3, 0, 1, 2, 4]
# [1, 2, 3, 1, 2, 3, 1, 2, 3]

# %%
l1 = [1,2,3] 
l2 = [1,2,3] 

print(l1 == l2) 

if 1 in l1:
    print("1 exists")
# Out:
# True
# 1 exists

# %%
# Operations in list 
l1 = [1,2,3,4] 

l1.append(5) 

print(l1) # 1,2,3,4,5

l1.pop() 
print(l1) # 1,2,3,4

print((1, "hi"))
# Out:
# [1, 2, 3, 4, 5]
# [1, 2, 3, 4]
# (1, 'hi')
