# %%
# 20.4/10 
x = 20.10 
y = 10 
print(x/y) 

print(x//y) #f loor value 
print(x * y) # x into y
print(x ** y) # x power y
# Out:
# 2.0100000000000002
# 2.0
# 201.0
# 10763674952097.703

# %%
print(10 << 1) # multiply 

print(10 >> 1) # divide
# Out:
# 20
# 5

# %%
x: bool = False 

print(x)
print(type(x))
# Out:
# False
# <class 'bool'>

# %%
string: str = "varmil"

print(string[1:4])
print(string[0:6:2]) # increase by 2 
print(string[::-1]) #reverse a string 

print(len(string)) 
x = [1,2,4,5,6,435,45,454,54,54] 
print(len(x)) 

print(x[9]) #index
# Out:
# arm
# vri
# limrav
# 6
# 10
# 54

# %%
arr = [1, "hey", 2,3,4,5,6] 
print(arr)
# Out:
# [1, 'hey', 2, 3, 4, 5, 6]

# %%
# tuple 
t = (1, "hey")
print(t) 

t = (2)
print(t)
# Out:
# (1, 'hey')
# 2

# %%
dictt = {1: "hey"} 

print(dictt[1])
print(dictt.keys()) 
print(dictt.values())

d2 = {} 

d2[2] = "Hello"  
print(d2) 
print(type(d2))

print(d2.get(3))
# Out:
# hey
# dict_keys([1])
# dict_values(['hey'])
# {2: 'Hello'}
# <class 'dict'>
# None
